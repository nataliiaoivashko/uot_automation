# %%
print("Assignment 1 Python class Ivashko Nataliia")
print("="*30)
print("Question 1 (5 marks)")
print("="*30)
"Create a list object which consists of the folowing digits: 1,5,6,7,8,9,11"

print("Creating a list object which consists of the folowing digits: 1,5,6,7,8,9,11")
list1 = [1,5,6,7,8,9,11]
print("list1:")
print(list1)

print("="*30)

"Write a Python program which returns the first and last value of the list. The output should be [1,11]"

print("Writing a Python program which returns the first and last value of the list. The output should be [1,11]")
print("the first value of the list is:")
print(list1[0])
print("the last value of the list is:")
print(list1[-1])
print("="*30)
"Write a Python program which returns each value of the list multiplied by 3 (for example, 1 3, 5 3, etc.)"

print("Writing a Python program which returns each value of the list multiplied by 3 (for example, 1 3, 5 3, etc.)")
print("old list")
print(list1)
"creating a new empty list"
my_new_list1 = []
"adding new elements to the new list, by taking elements from the old list and mulitplying each by 3 using loop"
for i in list1:
    my_new_list1.append(i * 3)
print("new list")
print(my_new_list1)

print("="*30)

print("Question 2 (5 marks)")
print("="*30)
"""Define a custom function which can take a list as an input, and pull out or display 
only the values divisible by 3, in order from smallest to largest. 
For example, if the list [1,12,7,3] was passed through the function, 
the output should be [3,12] since these two integers are divisible by 3, 
ordered from smallest to largest. Test your function on the following lists:
[1,6,8,12,7,24,3] -- the output should be [3,6,12,24]
[2,18,9,5,13,30,6] -- the output should be [6,9,18,30]"""

print("function which takes a list as an input, and displays only the values divisible by 3, in order from smallest to largest.")
print("old lists")
list2 = [1,6,8,12,7,24,3]
list22 = [2,18,9,5,13,30,6]
print(list2)
print(list22)
print("new lists")
list3 = []
list33 = []

for i in list2:
    if i % 3 != 0:
        continue
    list3.append(i)
    list3.sort()
print(list3)

for i in list22:
    if i % 3 != 0:
        continue
    list33.append(i)
    list33.sort()
print(list33)

print("="*30)

"creating a function"
def listfunction(userlist):
    print("old list")
    print(userlist)
    print("new list")
    newlist = []
    for i in userlist:
        if i % 3 != 0:
            continue
        newlist.append(i)
        newlist.sort()
    print(newlist)
"calling-using the finction"
new_sorted_list = listfunction(list2)
print(new_sorted_list)
new_sorted_list = listfunction(list22)
print(new_sorted_list)

print("="*30)

print("Question 3 (5 marks)")
"""
Question 3 (5 marks):
Given a set of coordinates of a line (x1,y1) and (x2,y2), 
write a custom Python function which can calculate the slope of the line 
(change in y divided by change in x). 
Test your function with the following sets of coordinates:

(1,2) and (7,10)
(3,4) and (13,17)
(7,6) and (11,2)
"""
print("="*30)


def slopefunction(userlist1, userlist2):
    print("Given are the coordinates:")
    print(userlist1)
    print(userlist2)
        
    print("The difference between the last elements of the lists:")
    numerator = userlist2[-1] - userlist1[-1]
    print(numerator)
    print("The difference between the first value of the lists:")
    denominator = userlist2[0] - userlist1[0]
    print(denominator)
    print("The slope value is:")
    slopevalue = numerator / denominator
    if slopevalue != 0:
        return print(slopevalue)
        
    else:
        print("Division by zero is impossible")
    

"calling-using the slope calculator function"
list_a = [1,2]
list_b = [7,10]
my_slope_calc = slopefunction(list_a,list_b)
list_c = [3,4]
list_d = [13,17]
my_slope_calc = slopefunction(list_c,list_d)
list_e = [7,6]
list_f = [11,2]
my_slope_calc = slopefunction(list_e,list_f)
# Out:
# Assignment 1 Python class Ivashko Nataliia
# ...
# Question 1 (5 marks)
# ...
# Creating a list object which consists of the folowing digits: 1,5,6,7,8,9,11
# list1:
# [1, 5, 6, 7, 8, 9, 11]
# ...
# Writing a Python program which returns the first and last value of the list. The output should be [1,11]
# the first value of the list is:
# 1
# the last value of the list is:
# 11
# ...
# Writing a Python program which returns each value of the list multiplied by 3 (for example, 1 3, 5 3, etc.)
# old list
# [1, 5, 6, 7, 8, 9, 11]
# new list
# [3, 15, 18, 21, 24, 27, 33]
# ...
# Question 2 (5 marks)
# ...
# function which takes a list as an input, and displays only the values divisible by 3, in order from smallest to largest.
# old lists
# [1, 6, 8, 12, 7, 24, 3]
# [2, 18, 9, 5, 13, 30, 6]
# new lists
# [3, 6, 12, 24]
# [6, 9, 18, 30]
# ...
# old list
# [1, 6, 8, 12, 7, 24, 3]
# new list
# [3, 6, 12, 24]
# None
# old list
# [2, 18, 9, 5, 13, 30, 6]
# new list
# [6, 9, 18, 30]
# None
# ...
# Question 3 (5 marks)
# ...
